# %%
from match_nfa import *
from termcolor import colored, cprint
from count import *

# %%
n = matchNFA()

n.addState(0)
n.addState(1)
n.addState(2)
n.addState(3)
n.addState(4)
n.addState(5)
n.addState(6)
n.addState(7)
n.addState(8)
n.addState(9)

n.addInitial(0)
n.addFinal(4)
n.addFinal(7)
n.addFinal(8)

n.addTransition(0, 'a', 1)
n.addTransition(1, 'a', 2)
n.addTransition(2, 'a', 3)

n.addTransition(3, 'a', 4)
n.addTransition(3, 'a', 5)

n.addTransition(5, 'a', 7)
n.addTransition(5, 'a', 6)

n.addTransition(6, 'a', 8)

n.addTransition(8, 'a', 9)
n.addTransition(7, 'a', 9)
n.addTransition(4, 'a', 9)

n.addTransitionStar(0, 0)
n.addTransitionStar(9, 9)

n.display()

# %%
w2 = "aaaaabaaaaa"
#x.table_matcher(w2)
d = n.table_matcher(w2)
f = n.enum_matches(d, w2)
# Out:
# {'a'}
# State 0
# 	 [(1, 1)]
# State 1
# 	 [(0, 1)]
# ----------------------
# State 0
# 	 [(2, 2)]
# State 1
# 	 [(1, 2)]
# State 2
# 	 [(0, 2)]
# ----------------------
# State 0
# 	 [(3, 3)]
# State 1
# 	 [(2, 3)]
# State 2
# 	 [(1, 3)]
# State 3
# 	 [(0, 3)]
# ----------------------
# State 0
# 	 [(4, 4)]
# State 1
# 	 [(3, 4)]
# State 2
# 	 [(2, 4)]
# State 3
# 	 [(1, 4)]
# State 4
# 	 [(0, 4)]
# State 5
# 	 [(0, 4)]
# ----------------------
# State 0
# 	 [(5, 5)]
# State 1
# 	 [(4, 5)]
# State 2
# 	 [(3, 5)]
# State 3
# 	 [(2, 5)]
# State 4
# 	 [(1, 5)]
# State 5
# 	 [(1, 5)]
# State 9
# 	 [(0, 5)]
# State 6
# 	 [(0, 5)]
# State 7
# 	 [(0, 5)]
# ----------------------
# State 0
# 	 [(6, 6)]
# ----------------------
# State 0
# 	 [(7, 7)]
# State 1
# 	 [(6, 7)]
# ----------------------
# State 0
# 	 [(8, 8)]
# State 1
# 	 [(7, 8)]
# State 2
# 	 [(6, 8)]
# ----------------------
# State 0
# 	 [(9, 9)]
# State 1
# 	 [(8, 9)]
# State 2
# 	 [(7, 9)]
# State 3
# 	 [(6, 9)]
# ----------------------
# State 0
# 	 [(10, 10)]
# State 1
# 	 [(9, 10)]
# State 2
# 	 [(8, 10)]
# State 3
# 	 [(7, 10)]
# State 4
# 	 [(6, 10)]
# State 5
# 	 [(6, 10)]
# ----------------------
# State 0
# 	 [(11, 11)]
# State 1
# 	 [(10, 11)]
# State 2
# 	 [(9, 11)]
# State 3
# 	 [(8, 11)]
# State 4
# 	 [(7, 11)]
# State 5
# 	 [(7, 11)]
# State 9
# 	 [(6, 11)]
# State 6
# 	 [(6, 11)]
# State 7
# 	 [(6, 11)]
# ----------------------
# State 4 matches (4):
# Match: aaaaabaaaaa => (0, 4)
# Match: aaaaabaaaaa => (1, 5)
# Match: aaaaabaaaaa => (6, 10)
# Match: aaaaabaaaaa => (7, 11)
# State 7 matches (2):
# Match: aaaaabaaaaa => (0, 5)
# Match: aaaaabaaaaa => (6, 11)
# Total matches: 6

# %%
w1 = "(a+aa)%"
regGrammar = lark.Lark.open("lang/regexp_test.lark", start="rege", parser="lalr")
tree = regGrammar.parse(w1)
reg = BuildRegexp(context={"sigma": None}).transform(tree)
reg.setSigma(reg.setOfSymbols())
x : matchNFA = reg.toNFA("nfaPosCount")
x.display()

w2 = "aaaaabaaaaa"
#x.table_matcher(w2)
d = x.table_matcher(w2)
f = x.enum_matches(d, w2)

# print("Number of matches:", sum([len(d[s]) for s in d]))

# print(d)
# Out:
# Symbol: @epsilon Counter: 0
# Symbol: a Counter: 1
# Symbol: a Counter: 2
# Symbol: a Counter: 3
# Symbol: a Counter: 4
# Symbol: a Counter: 5
# Symbol: b Counter: 6
# Symbol: a Counter: 7
# Symbol: a Counter: 8
# Symbol: a Counter: 9
# Symbol: a Counter: 10
# Symbol: a Counter: 11
# State 1 matches (30):
# Match: aaaaabaaaaa => (0, 1)
# Match: aaaaabaaaaa => (0, 2)
# Match: aaaaabaaaaa => (0, 3)
# Match: aaaaabaaaaa => (0, 4)
# Match: aaaaabaaaaa => (0, 5)
# Match: aaaaabaaaaa => (1, 2)
# Match: aaaaabaaaaa => (1, 3)
# Match: aaaaabaaaaa => (1, 4)
# Match: aaaaabaaaaa => (1, 5)
# Match: aaaaabaaaaa => (2, 3)
# Match: aaaaabaaaaa => (2, 4)
# Match: aaaaabaaaaa => (2, 5)
# Match: aaaaabaaaaa => (3, 4)
# Match: aaaaabaaaaa => (3, 5)
# Match: aaaaabaaaaa => (4, 5)
# Match: aaaaabaaaaa => (6, 7)
# Match: aaaaabaaaaa => (6, 8)
# Match: aaaaabaaaaa => (6, 9)
# Match: aaaaabaaaaa => (6, 10)
# Match: aaaaabaaaaa => (6, 11)
# Match: aaaaabaaaaa => (7, 8)
# Match: aaaaabaaaaa => (7, 9)
# Match: aaaaabaaaaa => (7, 10)
# Match: aaaaabaaaaa => (7, 11)
# Match: aaaaabaaaaa => (8, 9)
# Match: aaaaabaaaaa => (8, 10)
# Match: aaaaabaaaaa => (8, 11)
# Match: aaaaabaaaaa => (9, 10)
# Match: aaaaabaaaaa => (9, 11)
# Match: aaaaabaaaaa => (10, 11)
# State 3 matches (20):
# Match: aaaaabaaaaa => (0, 2)
# Match: aaaaabaaaaa => (0, 3)
# Match: aaaaabaaaaa => (0, 4)
# Match: aaaaabaaaaa => (0, 5)
# Match: aaaaabaaaaa => (1, 3)
# Match: aaaaabaaaaa => (1, 4)
# Match: aaaaabaaaaa => (1, 5)
# Match: aaaaabaaaaa => (2, 4)
# Match: aaaaabaaaaa => (2, 5)
# Match: aaaaabaaaaa => (3, 5)
# Match: aaaaabaaaaa => (6, 8)
# Match: aaaaabaaaaa => (6, 9)
# Match: aaaaabaaaaa => (6, 10)
# Match: aaaaabaaaaa => (6, 11)
# Match: aaaaabaaaaa => (7, 9)
# Match: aaaaabaaaaa => (7, 10)
# Match: aaaaabaaaaa => (7, 11)
# Match: aaaaabaaaaa => (8, 10)
# Match: aaaaabaaaaa => (8, 11)
# Match: aaaaabaaaaa => (9, 11)
# Total matches: 50
