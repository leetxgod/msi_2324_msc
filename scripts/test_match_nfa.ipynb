# %%
from match_nfa import *
from termcolor import colored, cprint
#from count import *

# %%
w1 = "(a+aa)(aaa+a)%"
regGrammar = lark.Lark.open("lang/regexp_test.lark", start="rege", parser="lalr")
tree = regGrammar.parse(w1)
reg = BuildRegexp(context={"sigma": None}).transform(tree)
reg.setSigma(reg.setOfSymbols())
x : matchNFA = reg.toNFA("nfaPosCount")
x.display()

w2 = "aaa"
#x.table_matcher(w2)
d = x.table_matcher(w2)
# f = x.enum_matches(d, w2)

# print("Number of matches:", sum([len(d[s]) for s in d]))

# print(d)
# Out:
# {'a'}
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/vx/73cw951x6mnfpr8__d4t1psr0000gn/T/ipykernel_70748/1964121455.py in <cell line: 0>()
#       9 w2 = "aaa"
#      10 #x.table_matcher(w2)
# ---> 11 d = x.table_matcher(w2)
#      12 # f = x.enum_matches(d, w2)
#      13
#
# ~/Desktop/College/msi_2324_msc/scripts/match_nfa.py in table_matcher(self, string)
#     300                                                                                                 new_row[last_row_end_state] = set()
#     301
# --> 302                                                                                         new_row[last_row_end_state].add((pos_tuple[0], symbol_counter))
#     303
#     304                                                                                         if last_row_end_state in self.Final:
#
# TypeError: 'int' object is not subscriptable
