# %%
import pandas as pd

# %%
pubs_full_df = pd.read_csv('../datasets/authenticus/publications_full_data_10K.csv')

# %%
pubs_full_df
# Out:
#          id                                     document_title subtitle  \
# 0         1  Fluorescence probes used for detection of reac...      NaN
# 1         2  Cooperative multi-robot systems: A study of vi...      NaN
# 2         3  The effect of dietary protein replacement by c...      NaN
# 3         4  Similar patterns of mitochondrial vulnerabilit...      NaN
# 4         5  The absence of ABCA1 decreases soluble ApoE le...      NaN
# ...     ...                                                ...      ...
# 9995  10007  4-hydroxy-6-methyl-3-(5-phenyl-2E,4E-pentadien...      NaN
# 9996  10008       Evolving time series forecasting ARMA models      NaN
# 9997  10009  Lepton mixing angle theta(13)=0 with a horizon...      NaN
# 9998  10010  Starch-chitosan hydrogels prepared by reductiv...      NaN
# 9999  10011             On the Krall-type discrete polynomials      NaN
#
#                                          authors_string  year_published  \
# ...
